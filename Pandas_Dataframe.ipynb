# %% [markdown]
# <a href="https://colab.research.google.com/github/kumoromilee/BasicProg_DataViz65/blob/main/Pandas_Dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Meta Data=Data that deswcribes data

# %%
import pandas as pd

# %% [markdown]
# ##csv= comma separated value

# %% [markdown]
# ##นำ Data เข้า
#  -upload to colab
#  -link with google drive

# %% [markdown]
# ##uploaed data to colab

# %%
data0 = pd.read_csv ('/opendata_project.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-a0d06842f9e8> in <module>()
# ----> 1 data0 = pd.read_csv ('/opendata_project.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
data0.head()

# %% [markdown]
# ##link with google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data1=pd.read_csv('/content/drive/MyDrive/BPDV65/opendata_unittype.csv')
data1.head()
# Out:
#    row_number     unittype_id    project_id             name_th  \
# 0       27501   unittype_9565  project_2446           2 Bedroom
# 1       28777  unittype_10267  project_3543  บ้านแฝดสองชั้น Z-2
# 2       28865    unittype_471   project_143    1 Bedroom Type B
# 3       24988  unittype_19506  project_7766    Studio Floor 1-2
# 4       38596  unittype_10290  project_3551                TH 3
#
#    propertytype_id propertytype_name_en propertytype_name_th  \
# 0                2                Condo                คอนโด
# 1            20000           Twin house              บ้านแฝด
# 2                2                Condo                คอนโด
# 3                2                Condo                คอนโด
# 4                3             Townhome             ทาวน์โฮม
#
#    area_total_min_wa  area_usable_min  price_min  ...  count_room_guest  \
# 0                NaN             37.3  2500000.0  ...               1.0
# ...

# %%
data1.tail(10)
# Out:
#        row_number               unittype_id                project_id  \
# 42615       36172            unittype_34140             project_14663
# 42616       28981            unittype_25373             project_10133
# 42617       35109             unittype_1459               project_711
# 42618       22299            unittype_13674              project_5356
# 42619       11944            unittype_34884             project_15005
# 42620       37109            unittype_38508             project_16864
# 42621          14            unittype_14016              project_5275
# 42622       41009  617bde1687dd2300149d2195  617bdd47f62011001350de07
# 42623        9333            unittype_37375             project_16389
# 42624         780            unittype_17011              project_6762
#
#                    name_th  propertytype_id propertytype_name_en  \
# 42615            2 Bedroom                2                Condo
# ...

# %%
data1.shape
# Out:
# (42625, 27)

# %% [markdown]
# ##Explore data

# %%
data1.describe()
# Out:
#          row_number  propertytype_id  area_total_min_wa  area_usable_min  \
# count  42625.000000     42625.000000        3747.000000     36999.000000
# mean   21313.000000       938.471859          44.413819       139.286943
# std    12304.921949      4220.823322          21.502884       111.939963
# min        1.000000         1.000000           1.000000        14.000000
# 25%    10657.000000         1.000000          23.000000        60.000000
# 50%    21313.000000         2.000000          50.000000       125.000000
# 75%    31969.000000         3.000000          60.000000       179.000000
# max    42625.000000     20000.000000         335.000000      4350.000000
#
#           price_min  count_airconditioner  count_elevator  \
# count  3.542800e+04           1780.000000             0.0
# mean   5.569699e+06              2.465730             NaN
# std    1.117088e+07              1.512717             NaN
# min    1.000000e+05              1.000000             NaN
# ...

# %% [markdown]
# #count นับจำนวนแถว แต่ละแถวไม่ดเหมือนกัน แปลว่า นับเฉพาะที่ไม่ใช่ค่าว่าง

# %% [markdown]
# #บ้านที่แพงที่สุดมีราคาเท่าไหร่ 5.800000e+08 เท่ากับ 58 ล้าน
# #บ้านที่มีที่จอดรถเยอะที่สุด 10

# %% [markdown]
# ##ชี้ค่าในตาราง (indexing)

# %%
data1['propertytype_name_en'][42619]
# Out:
# 'Detached House'

# %%
data1['propertytype_name_en']
# Out:
# 0                 Condo
# 1            Twin house
# 2                 Condo
# 3                 Condo
# 4              Townhome
#               ...
# 42620    Detached House
# 42621    Detached House
# 42622          Townhome
# 42623    Detached House
# 42624    Detached House
# Name: propertytype_name_en, Length: 42625, dtype: object

# %%
data1.iloc[42619,5]
# Out:
# 'Detached House'

# %%
data1.iloc[-6,5]
# Out:
# 'Detached House'

# %% [markdown]
# ##Table Slicing

# %%
data1.iloc[-20:,7:10]
# Out:
#        area_total_min_wa  area_usable_min   price_min
# 42605                NaN              NaN   1300000.0
# 42606                NaN            349.0  18000000.0
# 42607                NaN             71.0  17000000.0
# 42608                NaN              NaN         NaN
# 42609                NaN              NaN         NaN
# 42610                NaN            250.0   5990000.0
# 42611                NaN              NaN         NaN
# 42612                NaN            154.0   4800000.0
# 42613               50.0            105.0   1900000.0
# 42614                NaN            142.1   4880000.0
# 42615                NaN             60.0   3500000.0
# 42616                NaN            200.0         NaN
# 42617                NaN              NaN         NaN
# 42618                NaN            130.0  36500000.0
# 42619                NaN            353.0  23590000.0
# 42620                NaN            157.0         NaN
# ...

# %% [markdown]
# ##Table Query

# %%
data1[data1['propertytype_name_en']=='Condo'] ## ใช้ logical condition ในการเลือก data
# Out:
#        row_number     unittype_id     project_id                      name_th  \
# 0           27501   unittype_9565   project_2446                    2 Bedroom
# 2           28865    unittype_471    project_143             1 Bedroom Type B
# 3           24988  unittype_19506   project_7766             Studio Floor 1-2
# 10           5238  unittype_15162   project_4107             Studio Floor 5-8
# 14          29911  unittype_25780  project_10313                    1 Bedroom
# ...           ...             ...            ...                          ...
# 42590       23548  unittype_15279   project_3976  1 Bedroom Tower 1 Floor 5-6
# 42602       39384   unittype_3476    project_812             2 Bedroom Type A
# 42604        1058   unittype_7949   project_2641            Typical 1 Bedroom
# 42607       13546  unittype_40152  project_17505                    2 Bedroom
# 42615       36172  unittype_34140  project_14663                    2 Bedroom
#
# ...

# %%
data1['propertytype_name_en']=='Condo'
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4        False
#          ...
# 42620    False
# 42621    False
# 42622    False
# 42623    False
# 42624    False
# Name: propertytype_name_en, Length: 42625, dtype: bool

# %% [markdown]
# หาพื้นที่บ้าน
#
# ---

# %%
data1[data1['price_min']>10000000].describe()
# Out:
#          row_number  propertytype_id  area_total_min_wa  area_usable_min  \
# count   3481.000000      3481.000000         304.000000      3354.000000
# mean   21066.205401       215.859523          52.622796       286.948606
# std    12478.117102      2035.944151          31.406177       185.081647
# min        1.000000         1.000000           1.000000        30.000000
# 25%     9796.000000         1.000000          30.000000       155.000000
# 50%    21525.000000         1.000000          51.400000       265.000000
# 75%    32420.000000         2.000000          72.625000       362.750000
# max    42620.000000     20000.000000         335.000000      2548.000000
#
#           price_min  count_airconditioner  count_elevator  \
# count  3.481000e+03            138.000000             0.0
# mean   2.577675e+07              4.536232             NaN
# std    2.789259e+07              2.015123             NaN
# min    1.003000e+07              1.000000             NaN
# ...

# %% [markdown]
# ##Quiz 4
# 1. ราคาเฉลี่ยของบ้านที่มีราคาระหว่าง 3-5 ล้านบาท
# 2. พื้นที่ของ และ จำนวนห้องนอนของบ้านที่แพงที่สุด
# 3. จำนวนที่จอดรถและห้องน้ำของบ้านที่ถูกที่สุด
# 4. ชนิดของบ้านที้่แพงที่สุด
# 5. บ้่านชนิดไหนมีปณิมาณมากทึ่สุด

# %% [markdown]
# ###1.ราคาเฉลี่ยของบ้านที่มีราคาระหว่าง 3-5 ล้านบาท

# %% [markdown]
# ค่าเฉลี่ย คือ 5.765838e+06

# %%
data1[data1['price_min']>3000000&5000000].describe()
# Out:
#          row_number  propertytype_id  area_total_min_wa  area_usable_min  \
# count  34109.000000     34109.000000        3307.000000     30590.000000
# mean   20766.342959       953.850890          44.065540       139.298266
# std    12359.387053      4256.530342          21.673645       108.592023
# min        1.000000         1.000000           1.000000        16.000000
# 25%     9641.000000         1.000000          22.500000        64.000000
# 50%    20872.000000         2.000000          50.000000       125.000000
# 75%    31526.000000         3.000000          60.000000       177.000000
# max    42625.000000     20000.000000         335.000000      4350.000000
#
#           price_min  count_airconditioner  count_elevator  \
# count  3.410900e+04           1614.000000             0.0
# mean   5.765838e+06              2.537794             NaN
# std    1.133928e+07              1.515204             NaN
# min    8.040000e+05              1.000000             NaN
# ...

# %%
m  = data1[ (data1['price_min']>=3000000) & (data1['price_min'] <=5000000 ) ].describe() # นำข้อมูลราคาบ้านเข้าตาราง m
me = m.iloc[1,4] # เลือก column และ row ที่สนใจ (mean) และใส่ตัวแปรเป็น me 
print(f'ราคาเฉลี่ยของบ้านที่มีราคาระหว่าง 3-5 ล้านบ้าน ประมาณ {me:,.2f} บาท' )
# Out:
# ราคาเฉลี่ยของบ้านที่มีราคาระหว่าง 3-5 ล้านบ้าน ประมาณ 3,922,594.02 บาท

# %% [markdown]
# ###2.พื้นที่ของ และ จำนวนห้องนอนของบ้านที่แพงที่สุด

# %%
data1['price_min'].max()
# Out:
# 580000000.0

# %%
P = data1[data1['price_min']==580000000.0] # นำข้อมูลของบ้านที่แพงที่สุดเข้าตาราง P #หรือใส่ ==data1['price_min'].max()
P
# Out:
#        row_number     unittype_id     project_id    name_th  propertytype_id  \
# 33122        8629  unittype_37324  project_16305  Penthouse                2
#
#       propertytype_name_en propertytype_name_th  area_total_min_wa  \
# 33122                Condo                คอนโด                NaN
#
#        area_usable_min    price_min  ...  count_room_guest  \
# 33122           1182.0  580000000.0  ...               NaN
#
#        count_room_kitchen  count_room_living  count_room_maid  \
# 33122                 NaN                NaN              NaN
#
#        count_room_storage  count_room_utility         date_created  \
# 33122                 NaN                 NaN  2021-11-12 13:20:31
#
#               date_updated  source  \
# 33122  2020-10-14 00:55:50  baania
#
#                                             url_unittype
# 33122  https://baania.com/th/project/เดอะ-สุโขทัย-เรส...
#
# [1 rows x 27 columns]

# %%
am = P['area_usable_min'][33122] # หาจำนวนพื้นที่ของบ้านที่แพงที่สุด โดยใช้การชี้ค่าในตาราง
cb = P['count_room_bed'][33122]  # หาจำนวนห้องนอนของบ้านที่แพงที่สุด โดยใช้การชี้ค่าในตาราง
print(f'พื้นที่สอยของบ้านที่แพงที่สุดมีพื้นที่ประมาณ {am:,} ตารางเมตร และจำนวนห้องนอนของบ้านที่แพงที่สุดมีจำนวน {cb:.0f} ห้อง')
# Out:
# พื้นที่สอยของบ้านที่แพงที่สุดมีพื้นที่ประมาณ 1,182.0 ตารางเมตร และจำนวนห้องนอนของบ้านที่แพงที่สุดมีจำนวน 3 ห้อง

# %% [markdown]
# ###3.จำนวนที่จอดรถและห้องน้ำของบ้านที่ถูกที่สุด

# %%
data1['price_min'].min() # หาบ้านที่ราคาถูกที่สุด
# Out:
# 100000.0

# %%
C = data1[data1['price_min']==100000.0] # นำข้อมูลของบ้านที่ถูกที่สุดเข้าตาราง C
C
# Out:
#        row_number     unittype_id    project_id    name_th  propertytype_id  \
# 8640        28996  unittype_18085  project_7286  1 Bedroom                2
# 11019         808  unittype_18253  project_7374  1 Bedroom                2
# 17941       29386  unittype_19041  project_7623  1 Bedroom                2
# 30364         490  unittype_15924  project_6214     Studio                2
#
#       propertytype_name_en propertytype_name_th  area_total_min_wa  \
# 8640                 Condo                คอนโด                NaN
# 11019                Condo                คอนโด                NaN
# 17941                Condo                คอนโด                NaN
# 30364                Condo                คอนโด                NaN
#
#        area_usable_min  price_min  ...  count_room_guest  count_room_kitchen  \
# 8640              33.0   100000.0  ...               NaN                 NaN
# 11019             24.0   100000.0  ...               NaN                 NaN
# ...

# %%
c1 = C['count_room_bed'][8640]
c2 = C['count_room_bed'][11019]
c3 = C['count_room_bed'][17941]
c4 = C['count_room_bed'][30364]
p1 = C['count_parking'][8640]
p2 = C['count_parking'][11019]
p3 = C['count_parking'][17941]
p4 = C['count_parking'][30364]
print(f'จำนวนที่จอดรถของบ้านที่ถูกที่สุดมี {c1},{c2},{c3},{c4} ตามลำดับ และจำนวนห้องน้ำของบ้านที่ถูกที่สุดมี {p1},{p2},{p3},{p4} ตามลำดับ') #มีบ้าน4หลังที่ถูกที่สุด
# Out:
# จำนวนที่จอดรถของบ้านที่ถูกที่สุดมี 1.0,1.0,1.0,0.0 ตามลำดับ และจำนวนห้องน้ำของบ้านที่ถูกที่สุดมี nan,nan,nan,nan ตามลำดับ

# %% [markdown]
# ### 4.ชนิดของบ้านที่แพงที่สุด

# %%
T= P['propertytype_name_en'][33122]
print(f'ชนิดของบ้านที่แพงที่สุดคือ {T}')
# Out:
# ชนิดของบ้านที่แพงที่สุดคือ Condo

# %% [markdown]
# ###5.บ้านชนิดไหนมีปริมาณมากที่สุด

# %%
X  = data1['propertytype_name_en'].describe() # เลือก column ชนิดบ้าน ใช้.describe() ดูรายละเอียดภายใน column และตั้งเป็นตัวแปร X
X
# Out:
# count              42625
# unique                11
# top       Detached House
# freq               17670
# Name: propertytype_name_en, dtype: object

# %%
X2 = X['top'] 
print(f'ชนิดบ้านที่มีปริมาณมากที่สุดคือ {X2}')
# Out:
# ชนิดบ้านที่มีปริมาณมากที่สุดคือ Detached House
